# %%
import pandas as pd
import numpy as np

# %%
food = pd.read_csv("USDA-data.csv")

# %%
food.columns
# Out:
# Index(['ID', 'FoodGroup', 'ShortDescrip', 'Descrip', 'CommonName', 'MfgName',
#        'ScientificName', 'Energy_kcal', 'Protein_g', 'Fat_g', 'Carb_g',
#        'Sugar_g', 'Fiber_g', 'VitA_mcg', 'VitB6_mg', 'VitB12_mcg', 'VitC_mg',
#        'VitE_mg', 'Folate_mcg', 'Niacin_mg', 'Riboflavin_mg', 'Thiamin_mg',
#        'Calcium_mg', 'Copper_mcg', 'Iron_mg', 'Magnesium_mg', 'Manganese_mg',
#        'Phosphorus_mg', 'Selenium_mcg', 'Zinc_mg', 'VitA_USRDA', 'VitB6_USRDA',
#        'VitB12_USRDA', 'VitC_USRDA', 'VitE_USRDA', 'Folate_USRDA',
#        'Niacin_USRDA', 'Riboflavin_USRDA', 'Thiamin_USRDA', 'Calcium_USRDA',
#        'Copper_USRDA', 'Magnesium_USRDA', 'Phosphorus_USRDA', 'Selenium_USRDA',
#        'Zinc_USRDA'],
#       dtype='object')

# %%
food = food.iloc[:, 0: 30]

# %%
food.fillna("No name", inplace=True)

# %%
food.drop("ShortDescrip", axis=1, inplace=True)

# %%
food.FoodGroup.unique()
# Out:
# array(['Dairy and Egg Products', 'Spices and Herbs', 'Baby Foods',
#        'Fats and Oils', 'Poultry Products', 'Soups, Sauces, and Gravies',
#        'Sausages and Luncheon Meats', 'Breakfast Cereals', 'Snacks',
#        'Fruits and Fruit Juices', 'Pork Products',
#        'Vegetables and Vegetable Products', 'Nut and Seed Products',
#        'Beef Products', 'Beverages', 'Finfish and Shellfish Products',
#        'Legumes and Legume Products', 'Lamb, Veal, and Game Products',
#        'Baked Products', 'Sweets', 'Cereal Grains and Pasta',
#        'Fast Foods', 'Meals, Entrees, and Side Dishes',
#        'American Indian/Alaska Native Foods', 'Restaurant Foods'],
#       dtype=object)

# %%
food
# Out:
#          ID                       FoodGroup  \
# 0      1001          Dairy and Egg Products
# 1      1002          Dairy and Egg Products
# 2      1003          Dairy and Egg Products
# 3      1004          Dairy and Egg Products
# 4      1005          Dairy and Egg Products
# ...     ...                             ...
# 8613  83110  Finfish and Shellfish Products
# 8614  90240  Finfish and Shellfish Products
# 8615  90480                          Sweets
# 8616  90560  Finfish and Shellfish Products
# 8617  93600  Finfish and Shellfish Products
#
#                                                 Descrip CommonName  MfgName  \
# 0                                        Butter, salted    No name  No name
# 1                            Butter, whipped, with salt    No name  No name
# 2                                 Butter oil, anhydrous    No name  No name
# 3                                          Cheese, blue    No name  No name
# 4                                         Cheese, brick    No name  No name
# ...                                                 ...        ...      ...
# 8613                             Fish, mackerel, salted    No name  No name
# 8614  Mollusks, scallop, (bay and sea), cooked, steamed    No name  No name
# 8615                                        Syrup, Cane    No name  No name
# 8616                               Mollusks, snail, raw    No name  No name
# 8617                                 Turtle, green, raw    No name  No name
#
#      ScientificName  Energy_kcal  Protein_g  Fat_g  Carb_g  ...  \
# 0           No name        717.0       0.85  81.11    0.06  ...
# 1           No name        717.0       0.85  81.11    0.06  ...
# 2           No name        876.0       0.28  99.48    0.00  ...
# 3           No name        353.0      21.40  28.74    2.34  ...
# 4           No name        371.0      23.24  29.68    2.79  ...
# ...             ...          ...        ...    ...     ...  ...
# 8613        No name        305.0      18.50  25.10    0.00  ...
# 8614        No name        111.0      20.54   0.84    5.41  ...
# 8615        No name        269.0       0.00   0.00   73.14  ...
# 8616        No name         90.0      16.10   1.40    2.00  ...
# 8617        No name         89.0      19.80   0.50    0.00  ...
#
#       Riboflavin_mg  Thiamin_mg  Calcium_mg  Copper_mcg  Iron_mg  \
# 0             0.034       0.005        24.0       0.000     0.02
# 1             0.034       0.005        24.0       0.016     0.16
# 2             0.005       0.001         4.0       0.001     0.00
# 3             0.382       0.029       528.0       0.040     0.31
# 4             0.351       0.014       674.0       0.024     0.43
# ...             ...         ...         ...         ...      ...
# 8613          0.190       0.020        66.0       0.100     1.40
# 8614          0.024       0.012        10.0       0.033     0.58
# 8615          0.060       0.130        13.0       0.020     3.60
# 8616          0.120       0.010        10.0       0.400     3.50
# 8617          0.150       0.120       118.0       0.250     1.40
#
#       Magnesium_mg  Manganese_mg  Phosphorus_mg  Selenium_mcg  Zinc_mg
# 0              2.0         0.000           24.0           1.0     0.09
# 1              2.0         0.004           23.0           1.0     0.05
# 2              0.0         0.000            3.0           0.0     0.01
# 3             23.0         0.009          387.0          14.5     2.66
# 4             24.0         0.012          451.0          14.5     2.60
# ...            ...           ...            ...           ...      ...
# 8613          60.0         0.000          254.0          73.4     1.10
# 8614          37.0         0.029          426.0          21.7     1.55
# 8615          10.0         0.000            8.0           0.7     0.19
# 8616         250.0         0.000          272.0          27.4     1.00
# 8617          20.0         0.000          180.0          16.8     1.00
#
# [8618 rows x 29 columns]

# %%
food.to_csv("food.csv", index=False)
