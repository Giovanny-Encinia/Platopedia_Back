# %%
import pandas as pd
import numpy as np

# %% [markdown]
# First, I check the structure of the "xls" file, and I could determine which sheets I can to use for the analysis.

# %%
xls = pd.ExcelFile("FoodCompAfricaWest.xlsx")
food = pd.read_excel(xls, 2)

# %% [markdown]
# I eliminate the "\n" in the columns' name

# %%
columns = food.columns.to_list()
columns = [element.replace('\n', ' ').upper() for element in columns]
food.columns = columns

# %% [markdown]
# I will eliminate the rows with a number of N/A values greater than 44 also I will eliminate the first two rows.

# %%
condition = food.isna().sum(axis=1) > 44
food.drop(food[condition].index, inplace=True)
food.drop(index=[0,1], inplace=True)

# %% [markdown]
# In own dataframe in the last column exist diferent types of data so I handle the data and I eliminated the "[]", and I maked new data for a new column that will especify the method by wich the creators of the table found the phytatic acid.

# %%
columns = food.columns
columns = columns[5:]

for col in columns:
    lista = food[col].to_list() # Data of the last column of Food df
    method = [] # New column in own dataframe
    copy_lista = lista[:]
    i = 0

    for num in copy_lista:

        try:
            if num.find("[") != -1:
                method.append(1)
                num = num.replace("[", "")
                num = num.replace("]", "")
                lista[i] = num
                ward = 1
            else:
                method.append(0)

        except AttributeError:
            method.append(0)

        i += 1
    
    if ward == 1:
        food[col] = lista
        food[col + ' METHOD'] = method

# %% [markdown]
# I change the data type of each column

# %%
for col in columns:
    food[col] = pd.to_numeric(food[col], errors="coerce")

# %% [markdown]
# Now, I will find the food group's names

# %%
condition_sep = food.isna().sum(axis=1) > 43
group_index = food[condition_sep].index.to_list()

# %% [markdown]
# I will create the diferents dataframe of the groups of food
#
# The name of the list of dataframe groups is group_food

# %%
group_food = [] # Save the data
copy = group_index[:] # Ward for handling data

try:
    
    for index in group_index:
        iterador = iter(copy)
        copy.pop(0) # eliminate the first element of copy in each iteration
        next_index = next(iterador)
        begin = index
        end = next_index - 2
        # I use 2 because previously I erased the row
        group_food.append(food.loc[begin: end])
        
except StopIteration:
    begin = group_index[-1]
    end = food.iloc[-1].name
    group_food.append(food.loc[begin: end])

# %% [markdown]
# Se crea una lista en la cual se encuientran los distintos grupos de alimentos ( frutas, vegetales, raices, etc) abajo hay un ejemplo

# %%
group_food[1] # Starchy roots, tubers and their products
# Out:
#                                                   CODE  \
# 187  Starchy roots, tubers and their products/Racin...
# 188                                             02_093
# 189                                             02_091
# 190                                             02_092
# 191                                             02_021
# ..                                                 ...
# 279                                             02_078
# 280                                             02_035
# 281                                             02_050
# 282                                             02_080
# 283                                             02_079
#
#                                   FOOD NAME IN ENGLISH  \
# 187                                                NaN
# 188  Banakou né barâand kanss saagbo (Burkina Faso)...
# 189  Banakou né barâand moomd saagbo (Burkina Faso)...
# 190  Banakou né kou saagbo (Burkina Faso)*: foutou ...
# 191          Cassava, sweet, tuber, white flesh, dried
# ..                                                 ...
# 279  Yam, tuber, combined cultivars (Nigeria), boil...
# 280  Yam, tuber, combined cultivars (Nigeria), boil...
# 281                Yam, tuber, three-leaved, pale, raw
# 282  Yam, tuber, three-leaved, pale, boiled* (as pa...
# 283  Yam, tuber, three-leaved, pale, boiled* (witho...
#
#                                    FOOD NAME IN FRENCH      SCIENTIFIC NAME  \
# 187                                                NaN                  NaN
# 188  Banakou né barâand kanss saagbo (Burkina Faso)...                  NaN
# 189  Banakou né barâand moomd saagbo (Burkina Faso)...                  NaN
# 190  Banakou né kou saagbo (Burkina Faso)*: foutou ...                  NaN
# 191      Manioc, doux, tubercule, chair blanche, séché    Manihot esculenta
# ..                                                 ...                  ...
# 279  Igname, tubercule, cultivars combinés (Nigéria...       Dioscorea spp.
# 280  Igname, tubercule, cultivars combinés (Nigéria...       Dioscorea spp.
# 281  Igname, tubercule, à trois feuilles, chair pâl...  Dioscorea dumetorum
# 282  Igname, tubercule, à trois feuilles, chair pâl...  Dioscorea dumetorum
# 283  Igname, tubercule, à trois feuilles, chair pâl...  Dioscorea dumetorum
#
#                                        BIBLIOID/SOURCE  \
# 187                                                NaN
# 188                     calc. from recipe / de recette
# 189                     calc. from recipe / de recette
# 190                     calc. from recipe / de recette
# 191                           FAO(224), NG1112, 02_001
# ..                                                 ...
# 279                             calc. from / de 02_034
# 280                             calc. from / de 02_034
# 281  6N, 22N, dp10BIO, FAO(42), IN17(F018), NG1212,...
# 282                             calc. from / de 02_050
# 283                             calc. from / de 02_050
#
#     EDIBLE PORTION COEFFICIENT 1 (FROM AS PURCHASED TO AS DESCRIBED)  \
# 187                                                NaN
# 188                                                NaN
# 189                                                NaN
# 190                                                NaN
# 191                                                  1
# ..                                                 ...
# 279                                               0.82
# 280                                               0.82
# 281                                               0.82
# 282                                               0.81
# 283                                               0.81
#
#     ENERGY (KJ) ENERGY (KCAL) WATER (G) PROTEIN, TOTAL (G)  ...  \
# 187         NaN           NaN       NaN                NaN  ...
# 188         492           116      68.6                1.2  ...
# 189         489           115      69.2                1.1  ...
# 190         433           102      71.6                1.5  ...
# 191        1470           348       6.7                1.3  ...
# ..          ...           ...       ...                ...  ...
# 279         573           136      62.3                1.9  ...
# 280         573           136      62.3                1.9  ...
# 281         483           114      67.8                1.8  ...
# 282         509           120      66.1                1.9  ...
# 283         509           120      66.1                1.9  ...
#
#     FOLATE, DIETARY FOLATE EQUIVALENTS (MCG) METHOD VITAMIN B12 (MCG) METHOD  \
# 187                                               0                        0
# 188                                               0                        0
# 189                                               0                        0
# 190                                               0                        0
# 191                                               0                        0
# ..                                              ...                      ...
# 279                                               0                        0
# 280                                               0                        0
# 281                                               0                        0
# 282                                               0                        0
# 283                                               0                        0
#
#     VITAMIN C (MG) METHOD CHOLESTEROL (MG) METHOD  \
# 187                     0                       0
# 188                     0                       0
# 189                     0                       0
# 190                     0                       0
# 191                     0                       0
# ..                    ...                     ...
# 279                     0                       0
# 280                     0                       0
# 281                     0                       0
# 282                     0                       0
# 283                     0                       0
#
#     FATTY ACIDS, TOTAL SATURATED (G) METHOD  \
# 187                                       0
# 188                                       0
# 189                                       0
# 190                                       0
# 191                                       0
# ..                                      ...
# 279                                       0
# 280                                       0
# 281                                       0
# 282                                       0
# 283                                       0
#
#     FATTY ACIDS, TOTAL MONOUNSATURATED  (G) METHOD  \
# 187                                              0
# 188                                              0
# 189                                              0
# 190                                              0
# 191                                              0
# ..                                             ...
# 279                                              0
# 280                                              0
# 281                                              0
# 282                                              0
# 283                                              0
#
#     FATTY ACIDS, TOTAL POLYUNSATURATED (G) METHOD LINOLEIC ACID  (G) METHOD  \
# 187                                             0                         0
# 188                                             0                         0
# 189                                             0                         0
# 190                                             0                         0
# 191                                             0                         0
# ..                                            ...                       ...
# 279                                             0                         0
# 280                                             0                         0
# 281                                             0                         0
# 282                                             0                         0
# 283                                             0                         0
#
#     ALPHA-LINOLENIC ACID (G) METHOD  \
# 187                               0
# 188                               0
# 189                               0
# 190                               0
# 191                               0
# ..                              ...
# 279                               0
# 280                               0
# 281                               0
# 282                               0
# 283                               0
#
#     PHYTATE, TOTAL OR [PHYTATE, DETERMINED BY DIRECT PRECIPITATION] OR [PHYTATE, DETERMINED BY INDIRECT PRECIPITATION] (MG) METHOD
# 187                                                  0
# 188                                                  0
# 189                                                  1
# 190                                                  0
# 191                                                  0
# ..                                                 ...
# 279                                                  0
# 280                                                  0
# 281                                                  0
# 282                                                  0
# 283                                                  0
#
# [97 rows x 85 columns]
